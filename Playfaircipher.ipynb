# %%
key  = [[ord("L"),ord("G"),ord("D"),ord("B"),ord("A")],
        [ord("Q"),ord("M"),ord("H"),ord("E"),ord("C")],
        [ord("U"),ord("R"),ord("N"),ord("I"),ord("F")],
        [ord("X"),ord("V"),ord("S"),ord("O"),ord("K")],
        [ord("Z"),ord("Y"),ord("W"),ord("T"),ord("P")]]
plaintext = input("Enter the plaintext:")
plaintext=plaintext.upper()
plaintext = (plaintext.replace("J","I")) 
def remove(string): 
    return string.replace(" ", "")
plaintext = remove(plaintext)
length = len(plaintext)
for i in range (0,length): 
    if plaintext[i] == plaintext[i+1]:
        plaintext = plaintext[:i+1] + "Z" +plaintext[i+1:]
    if len(plaintext)%2 !=0: 
        plaintext = plaintext+"Z"

arr = [0 for q in range (0,len(plaintext))]
for c in range (0,len(plaintext)): 
    for j in range (0,len(key)):
           for k in range(0, len(key)):
               if ord(plaintext[c]) == key[j][k]:
                   arr[c] = j,k
arr2 = [0 for q1 in range(0,len(plaintext))]
for t in range(0,len(plaintext),2): 
    a1 = arr[t]
    a2 = arr[t+1]
    if a1[0] == a2[0]:          
        if a1[1] == 4:
            a1 = a1[0],0
            arr2[t] = a1
        else:
            a1 = a1[0], a1[1] + 1
            arr2[t]= a1

        if a2[1] == 4:
            a2 = a2[0],0
            arr2[t+1] = a2
        else:
            a2 = a2[0],a2[1]+1
            arr2[t+1] = a2

    elif a1[1] == a2[1]:          
        if a1[0] == 4:
            a1 = 4,a1[1]
            arr2[t] = a1
        else:
            a1 = a1[0] + 1, a1[1]
            arr2[t] = a1

        if a2[0]==4:
            a2= 0,a2[1]
            arr2[t+1] = a2
        else:
            a2 = a2[0]+1,a2[1]
            arr2[t+1] = a2
    else:                        
        c5 = a1
        a1 = a1[0],a2[1]
        a2 = a2[0],c5[1]
        arr2[t] = a1
        arr2[t+1] = a2
enc = ""

for qt in range (0, len(plaintext)):
    q1 = arr2[qt]
    enc = enc+(chr(key[q1[0]][q1[1]]))
print("Plain text is:"+plaintext.lower())
print("Encrypted text is:"+enc)
# Out:
# Enter the plaintext:helloo
# Plain text is:helzlozozz
# Encrypted text is:ECQLBXTXYY

# %%
key=input("Enter key ")
key=key.replace(" ", "")
key=key.upper()
def matrix(x,y,initial):
    return [[initial for i in range(x)] for j in range(y)]
    
result=list()
x = 'I'
for c in key:
    if c not in result:
        if c=='J':
            if x not in result:
                result.append('I')
        elif c=='J':
            if x in result:
                break
        else:
            result.append(c)
flag=0
for i in range(65,91): 
    if chr(i) not in result:
        if i==73 and chr(74) not in result:
            result.append("I")
            flag=1
        elif flag==0 and i==73 or i==74:
            pass    
        else:
            result.append(chr(i))
k=0
my_matrix=matrix(5,5,0) 
for i in range(0,5): 
    for j in range(0,5):
        my_matrix[i][j]=result[k]
        k+=1
print('The table is : ' ,my_matrix)

def locindex(c):
    loc=list()
    if c=='J':
        c='I'
    for i ,j in enumerate(my_matrix):
        for k,l in enumerate(j):
            if c==l:
                loc.append(i)
                loc.append(k)
                return loc
            
def encrypt():  
    msg=str(input("ENTER MSG:"))
    msg=msg.upper()
    msg=msg.replace(" ", "")    
    msg=msg.replace("J","I")
    i=0
    length = len(msg)
    if length%2 == 0:
        for j in range (0,length):
            if  msg[j] == msg[j+1]:
                 msg = msg[:j+1] + "X" +msg[j+1:]
#     else:
#         for j in range (0,length-1):
#             if  msg[j] == msg[j+1]:
#                  msg = msg[:j+1] + "X" +msg[j+1:]
    
    if len(msg)%2 == 1:
        msg = msg+"X"
    print("CIPHER TEXT:",end=' ')
    while i<len(msg):
        loc=list()
        loc=locindex(msg[i])
        loc1=list()
        loc1=locindex(msg[i+1])
        if loc[1]==loc1[1]:
            print("{}{}".format(my_matrix[(loc[0]+1)%5][loc[1]],my_matrix[(loc1[0]+1)%5][loc1[1]]),end=' ')
        elif loc[0]==loc1[0]:
            print("{}{}".format(my_matrix[loc[0]][(loc[1]+1)%5],my_matrix[loc1[0]][(loc1[1]+1)%5]),end=' ')  
        else:
            print("{}{}".format(my_matrix[loc[0]][loc1[1]],my_matrix[loc1[0]][loc[1]]),end=' ')    
        i=i+2         
    
encrypt()
# Out:
# Enter key NINJA
# The table is :  [['N', 'I', 'A', 'B', 'C'], ['D', 'E', 'F', 'G', 'H'], ['K', 'L', 'M', 'O', 'P'], ['Q', 'R', 'S', 'T', 'U'], ['V', 'W', 'X', 'Y', 'Z']]
# ENTER MSG:JITTER
# CIPHER TEXT: AW BR YS LW
